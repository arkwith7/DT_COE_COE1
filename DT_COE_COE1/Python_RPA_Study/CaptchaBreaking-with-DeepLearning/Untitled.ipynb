# %%
import sys
import numpy as np
import cv2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
im = cv2.imread('images/numbers100.jpg')
plt.imshow(im)
plt.show()

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5, 5), 0)
thresh = cv2.adaptiveThreshold(blur, 255, 1, 1, 11, 2)

# 윤곽 추출하기
contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[1]
# check OpenCV version
major = cv2.__version__.split('.')[0]
if major == '3':
    contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[1]
else:
    contours = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[1]

# print(contours)

for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)
    if h < 20: continue # 너무 작으면 건너뛰기
    red = (0, 0, 255)
    cv2.rectangle(im, (x, y), (x+w, y+h), red, 2)
# Out:
# [[[  1  -1  -1  -1]
#   [  2   0  -1  -1]
#   [  3   1  -1  -1]
#   [  4   2  -1  -1]
#   [  5   3  -1  -1]
#   [  6   4  -1  -1]
#   [  7   5  -1  -1]
#   [  8   6  -1  -1]
#   [  9   7  -1  -1]
#   [ 10   8  -1  -1]
#   [ 11   9  -1  -1]
#   [ 12  10  -1  -1]
#   [ 13  11  -1  -1]
#   [ 14  12  -1  -1]
#   [ 15  13  -1  -1]
#   [ 16  14  -1  -1]
#   [ 17  15  -1  -1]
#   [ 18  16  -1  -1]
#   [ 19  17  -1  -1]
#   [ 20  18  -1  -1]
#   [ 21  19  -1  -1]
#   [ 22  20  -1  -1]
#   [ 23  21  -1  -1]
#   [ 24  22  -1  -1]
#   [ 25  23  -1  -1]
#   [ 26  24  -1  -1]
#   [ 27  25  -1  -1]
#   [ 28  26  -1  -1]
#   [ 29  27  -1  -1]
#   [ 30  28  -1  -1]
#   [ 31  29  -1  -1]
#   [ 32  30  -1  -1]
#   [ 33  31  -1  -1]
#   [ 34  32  -1  -1]
#   [ 35  33  -1  -1]
#   [ 36  34  -1  -1]
#   [ 37  35  -1  -1]
#   [ 38  36  -1  -1]
#   [ 39  37  -1  -1]
#   [ 40  38  -1  -1]
#   [ 41  39  -1  -1]
#   [ 42  40  -1  -1]
#   [ 43  41  -1  -1]
#   [ 44  42  -1  -1]
#   [ 45  43  -1  -1]
# ...

# %%
cv2.imwrite('numbers-cnt.PNG', im)
image = mpimg.imread("numbers-cnt.PNG")
plt.imshow(image)
plt.show()
